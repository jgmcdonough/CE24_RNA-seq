# %% [markdown]
# # spliceR
# [spliceR paper](https://pmc.ncbi.nlm.nih.gov/articles/PMC3998036/)

# %% [markdown]
# ## 0. load libraries

# %%
library(tidyverse)

# %%
# Out:
# Warning message:
# “package ‘spliceR’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”
