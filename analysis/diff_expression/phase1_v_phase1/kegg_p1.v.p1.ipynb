# %% [markdown]
# # KEGG Analysis
#
# # Phase 1 vs. Phase 1
#
# Using `enrichKEGG` in the clusterProfiler package to investigate enrichment of KEGG categories in our DEGs

# %% [markdown]
# ## 0. load libraries

# %%
library(stringr)
library(dplyr)
library(ggplot2)
library(clusterProfiler)

# %% [markdown]
# ## 1. read CSVs
#
# read in as data frames

# %%
##### comparisons vs. control
# warm vs. control
w.c_deg <- read.csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/julia/CE_2024/CE24_RNA-seq/analysis/diff_expression/phase1_v_phase1/deseq_res_files/p1.DEG_warm_v_cont.csv')

# both vs. control
b.c_deg <- read.csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/julia/CE_2024/CE24_RNA-seq/analysis/diff_expression/phase1_v_phase1/deseq_res_files/p1.DEG_both_v_cont.csv')

# hyp vs. control
h.c_deg <- read.csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/julia/CE_2024/CE24_RNA-seq/analysis/diff_expression/phase1_v_phase1/deseq_res_files/p1.DEG_hyp_v_cont.csv')

##### other comparisons
# hyp vs. both
h.b_deg <- read.csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/julia/CE_2024/CE24_RNA-seq/analysis/diff_expression/phase1_v_phase1/deseq_res_files/p1.DEG_hyp_v_both.csv')

# warm vs. both
w.b_deg <- read.csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/julia/CE_2024/CE24_RNA-seq/analysis/diff_expression/phase1_v_phase1/deseq_res_files/p1.DEG_warm_v_both.csv')

# warm vs. hyp
w.h_deg <- read.csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/julia/CE_2024/CE24_RNA-seq/analysis/diff_expression/phase1_v_phase1/deseq_res_files/p1.DEG_warm_v_hyp.csv')

# %% [markdown]
# create a vector of entrez gene id (only numbers)

# %%
# remove leading LOC
wc <- str_replace(w.c_deg$X, 'LOC', '')
hc <- str_replace(h.c_deg$X, 'LOC', '')
bc <- str_replace(b.c_deg$X, 'LOC', '')
hb <- str_replace(h.b_deg$X, 'LOC', '')
wb <- str_replace(w.b_deg$X, 'LOC', '')
wh <- str_replace(w.h_deg$X, 'LOC', '')

# check it worked
head(hc)
# Out:
# [1] "111121183" "111120021" "111119724" "111119726" "111121216" "111125414"

# %%
universe_list <- read.csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/julia/CE_2024/CE24_RNA-seq/analysis/diff_expression/phase1_v_phase1/deseq_res_files/p1.warm_v_control.csv') 
universe_list <- str_replace(universe_list$X, 'LOC', '')
head(universe_list)
# Out:
# [1] "111116054" "111126949" "111110729" "111112434" "111120752" "111128944"

# %% [markdown]
# ## 2. run `enrichKEGG`

# %% [markdown]
# ### Phase 1 Warm vs. Control

# %%
wc.kegg <- enrichKEGG(
    gene = wc,
    organism = 'cvn',
    keyType = 'kegg',
    pvalueCutoff = 0.05,
    pAdjustMethod = 'BH',
    universe = universe_list)

head(wc.kegg)
# Out:
#          category   subcategory       ID
# cvn00910 Metabolism Energy metabolism cvn00910
#          Description                                                  GeneRatio
# cvn00910 Nitrogen metabolism - Crassostrea virginica (eastern oyster) 2/7
#          BgRatio pvalue       p.adjust    qvalue      geneID              Count
# cvn00910 30/5530 0.0005875247 0.002937624 0.001236894 111137424/111117514 2

# %% [markdown]
# ### Phase 1 Hypoxic vs. Control

# %%
hc.kegg <- enrichKEGG(
    gene = hc,
    organism = 'cvn',
    keyType = 'kegg',
    pvalueCutoff = 0.05,
    pAdjustMethod = 'BH',
    universe = universe_list)

head(hc.kegg)
# Out:
# --> No gene can be mapped....
#
# --> Expected input gene ID: 111111942,111131063,111131432,111121750,111117164,111128802
#
# --> return NULL...
# NULL

# %% [markdown]
# ### Phase 1 Both vs. Control

# %%
bc.kegg <- enrichKEGG(
    gene = bc,
    organism = 'cvn',
    keyType = 'kegg',
    pvalueCutoff = 0.05,
    pAdjustMethod = 'BH',
    universe = universe_list)

head(bc.kegg)
# Out:
#          category           subcategory              ID
# cvn00520 Metabolism         Carbohydrate metabolism  cvn00520
# cvn04977 Organismal Systems Digestive system         cvn04977
# cvn04142 Cellular Processes Transport and catabolism cvn04142
#          Description
# cvn00520 Amino sugar and nucleotide sugar metabolism - Crassostrea virginica (eastern oyster)
# cvn04977 Vitamin digestion and absorption - Crassostrea virginica (eastern oyster)
# cvn04142 Lysosome - Crassostrea virginica (eastern oyster)
#          GeneRatio BgRatio  pvalue       p.adjust     qvalue
# cvn00520 6/27      75/5530  1.200430e-06 2.881033e-05 2.148138e-05
# cvn04977 4/27      83/5530  6.365782e-04 7.638939e-03 5.695700e-03
# cvn04142 5/27      192/5530 2.073084e-03 1.658467e-02 1.236576e-02
#          geneID                                                      Count
# cvn00520 111119837/111124157/111125216/111125215/111127514/111125342 6
# cvn04977 111125053/111103328/111103330/111111573                     4
# cvn04142 111127514/111106922/111113026/111113028/111113029           5

# %% [markdown]
# ### Phase 1 Hypoxic vs. Both

# %%
hb.kegg <- enrichKEGG(
    gene = hb,
    organism = 'cvn',
    keyType = 'kegg',
    pvalueCutoff = 0.05,
    pAdjustMethod = 'BH',
    universe = universe_list)

head(hb.kegg)
# Out:
#          category           subcategory      ID
# cvn04977 Organismal Systems Digestive system cvn04977
#          Description
# cvn04977 Vitamin digestion and absorption - Crassostrea virginica (eastern oyster)
#          GeneRatio BgRatio pvalue     p.adjust  qvalue
# cvn04977 3/15      83/5530 0.00130242 0.0195363 0.01508065
#          geneID                        Count
# cvn04977 111103328/111103330/111111573 3

# %% [markdown]
# ### Phase 1 Warm vs. Both

# %%
wb.kegg <- enrichKEGG(
    gene = wb,
    organism = 'cvn',
    keyType = 'kegg',
    pvalueCutoff = 0.05,
    pAdjustMethod = 'BH',
    universe = universe_list)

head(wb.kegg)
# Out:
#      category subcategory ID Description GeneRatio BgRatio pvalue p.adjust
#      qvalue geneID Count

# %% [markdown]
# ### Phase 1 Warm vs. Hypoxic

# %%
wh.kegg <- enrichKEGG(
    gene = wh,
    organism = 'cvn',
    keyType = 'kegg',
    pvalueCutoff = 0.05,
    pAdjustMethod = 'BH',
    universe = universe_list)

head(wh.kegg)
# Out:
#      category subcategory ID Description GeneRatio BgRatio pvalue p.adjust
#      qvalue geneID Count
