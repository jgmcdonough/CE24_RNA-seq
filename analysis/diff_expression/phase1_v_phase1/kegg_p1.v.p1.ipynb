# %% [markdown]
# # KEGG Analysis
#
# # Phase 1 vs. Phase 1
#
# Using `enrichKEGG` in the clusterProfiler package to investigate enrichment of KEGG categories in our DEGs

# %% [markdown]
# ## 0. load libraries

# %%
library(stringr)
library(dplyr)
library(ggplot2)
library(clusterProfiler)

# %% [markdown]
# ## 1. read CSVs
#
# read in as data frames

# %%
##### comparisons vs. control
# warm vs. control
w.c_deg <- read.csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/julia/CE_2024/CE24_RNA-seq/analysis/diff_expression/phase1_v_phase1/deseq_res_files/DEGs/DEG_w_c.csv')

# both vs. control
b.c_deg <- read.csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/julia/CE_2024/CE24_RNA-seq/analysis/diff_expression/phase1_v_phase1/deseq_res_files/DEGs/DEG_b_c.csv')

# hyp vs. control
h.c_deg <- read.csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/julia/CE_2024/CE24_RNA-seq/analysis/diff_expression/phase1_v_phase1/deseq_res_files/DEGs/DEG_h_c.csv')

##### other comparisons
# hyp vs. both
h.b_deg <- read.csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/julia/CE_2024/CE24_RNA-seq/analysis/diff_expression/phase1_v_phase1/deseq_res_files/DEGs/DEG_h_b.csv')

# warm vs. both
w.b_deg <- read.csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/julia/CE_2024/CE24_RNA-seq/analysis/diff_expression/phase1_v_phase1/deseq_res_files/DEGs/DEG_w_b.csv')

# warm vs. hyp
w.h_deg <- read.csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/julia/CE_2024/CE24_RNA-seq/analysis/diff_expression/phase1_v_phase1/deseq_res_files/DEGs/DEG_h_w.csv')

# %% [markdown]
# create a vector of entrez gene id (only numbers)

# %%
# remove leading LOC
wc <- str_replace(w.c_deg$X, 'LOC', '')
hc <- str_replace(h.c_deg$X, 'LOC', '')
bc <- str_replace(b.c_deg$X, 'LOC', '')
hb <- str_replace(h.b_deg$X, 'LOC', '')
wb <- str_replace(w.b_deg$X, 'LOC', '')
wh <- str_replace(w.h_deg$X, 'LOC', '')

# check it worked
head(hc)
# Out:
# [1] "111121183" "111120021" "111119724" "111119726" "111125414" "111123780"

# %%
universe_list <- read.csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/julia/CE_2024/CE24_RNA-seq/analysis/diff_expression/phase1_v_phase1/deseq_res_files/all_genes/p1.warm_v_cont.csv') 
universe_list <- str_replace(universe_list$X, 'LOC', '')
head(universe_list)
# Out:
# [1] "111116054" "111126949" "111110729" "111112434" "111120752" "111128944"

# %% [markdown]
# ## 2. run `enrichKEGG`

# %% [markdown]
# ### Phase 1 Warm vs. Control

# %%
wc.kegg <- enrichKEGG(
    gene = wc,
    organism = 'cvn',
    keyType = 'kegg',
    pvalueCutoff = 0.05,
    pAdjustMethod = 'BH',
    universe = universe_list)

head(wc.kegg)
# Out:
# Reading KEGG annotation online: "https://rest.kegg.jp/link/cvn/pathway"...
#
# Reading KEGG annotation online: "https://rest.kegg.jp/list/pathway/cvn"...
#          category                       subcategory
# cvn00910 Metabolism                     Energy metabolism
# cvn04120 Genetic Information Processing Folding, sorting and degradation
#          ID
# cvn00910 cvn00910
# cvn04120 cvn04120
#          Description
# cvn00910 Nitrogen metabolism - Crassostrea virginica (eastern oyster)
# cvn04120 Ubiquitin mediated proteolysis - Crassostrea virginica (eastern oyster)
#          GeneRatio BgRatio  pvalue      p.adjust    qvalue
# cvn00910 2/6       27/5527  0.000340629 0.001362516 0.0007171138
# cvn04120 2/6       186/5527 0.015453701 0.030907402 0.0162670539
#          geneID              Count
# cvn00910 111137424/111117514 2
# cvn04120 111123894/111130636 2

# %% [markdown]
# ### Phase 1 Hypoxic vs. Control

# %%
hc.kegg <- enrichKEGG(
    gene = hc,
    organism = 'cvn',
    keyType = 'kegg',
    pvalueCutoff = 0.05,
    pAdjustMethod = 'BH',
    universe = universe_list)

head(hc.kegg)
# Out:
# --> No gene can be mapped....
#
# --> Expected input gene ID: 111127323,111138520,111134492,111109888,111111035,111109436
#
# --> return NULL...
# NULL

# %% [markdown]
# either all 53 DEGs are not annotated in the KEGG database, or none of the pathways are enriched - since below, there are some dfs that are empty, I think the prior hypothesis is true

# %% [markdown]
# ### Phase 1 Both vs. Control

# %%
bc.kegg <- enrichKEGG(
    gene = bc,
    organism = 'cvn',
    keyType = 'kegg',
    pvalueCutoff = 0.05,
    pAdjustMethod = 'BH',
    universe = universe_list)

head(bc.kegg)
# Out:
#          category           subcategory             ID
# cvn00520 Metabolism         Carbohydrate metabolism cvn00520
# cvn04977 Organismal Systems Digestive system        cvn04977
#          Description
# cvn00520 Amino sugar and nucleotide sugar metabolism - Crassostrea virginica (eastern oyster)
# cvn04977 Vitamin digestion and absorption - Crassostrea virginica (eastern oyster)
#          GeneRatio BgRatio pvalue       p.adjust     qvalue
# cvn00520 6/24      75/5527 5.655051e-07 1.187561e-05 8.333759e-06
# cvn04977 4/24      83/5527 3.996778e-04 4.196617e-03 2.944994e-03
#          geneID                                                      Count
# cvn00520 111119837/111124157/111125216/111125215/111127514/111125342 6
# cvn04977 111125053/111103328/111103330/111111573                     4

# %% [markdown]
# ### Phase 1 Hypoxic vs. Both

# %%
hb.kegg <- enrichKEGG(
    gene = hb,
    organism = 'cvn',
    keyType = 'kegg',
    pvalueCutoff = 0.05,
    pAdjustMethod = 'BH',
    universe = universe_list)

head(hb.kegg)
# Out:
#          category           subcategory      ID
# cvn04977 Organismal Systems Digestive system cvn04977
#          Description
# cvn04977 Vitamin digestion and absorption - Crassostrea virginica (eastern oyster)
#          GeneRatio BgRatio pvalue      p.adjust  qvalue
# cvn04977 3/14      83/5527 0.001054943 0.0147692 0.01110466
#          geneID                        Count
# cvn04977 111103328/111103330/111111573 3

# %% [markdown]
# ### Phase 1 Warm vs. Both

# %%
wb.kegg <- enrichKEGG(
    gene = wb,
    organism = 'cvn',
    keyType = 'kegg',
    pvalueCutoff = 0.05,
    pAdjustMethod = 'BH',
    universe = universe_list)

head(wb.kegg)
# Out:
#      category subcategory ID Description GeneRatio BgRatio pvalue p.adjust
#      qvalue geneID Count

# %% [markdown]
# so no enriched KEGG pathways

# %% [markdown]
# ### Phase 1 Warm vs. Hypoxic

# %%
wh.kegg <- enrichKEGG(
    gene = wh,
    organism = 'cvn',
    keyType = 'kegg',
    pvalueCutoff = 0.05,
    pAdjustMethod = 'BH',
    universe = universe_list)

head(wh.kegg)
# Out:
#      category subcategory ID Description GeneRatio BgRatio pvalue p.adjust
#      qvalue geneID Count

# %% [markdown]
# no enriched KEGG pathways
