# %% [markdown]
# # Vetting the new reference genome release
# The people behind the new genome release included a [txt file](https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/053/477/285/GCF_053477285.1_ASM5347728v1/Annotation_comparison/GCF_053477285.1_ASM5347728v1_compare_prev.txt.gz) to compare annotations in the old and new genome.
#
# Here, I'm going to take a look at this through exploratory analysis.

# %% [markdown]
# ## 0. load libraries

# %%
library(tidyverse)

# %% [markdown]
# ## 2. load files

# %%
annot <- read.csv('/scratch4/workspace/julia_mcdonough_student_uml_edu-novogene_dwnld/GCF_053477285.1_ASM5347728v1_compare_prev.txt', sep = '\t')
head(annot)
# Out:
#   X.gene.category  current.GeneID current.gene.biotype current.assembly.unit
# 1 Current-unmapped 144622103      protein_coding       GCF_053477295.1
# 2 Current-unmapped 144622104      protein_coding       GCF_053477295.1
# 3 Current-unmapped 144620484      pseudogene           GCF_053477295.1
# 4 Current-unmapped 144620485      pseudogene           GCF_053477295.1
# 5 Current-unmapped 144622102      protein_coding       GCF_053477295.1
# 6 Current-unmapped 144622102      protein_coding       GCF_053477295.1
#   current.genomic.accession current.gene.range current.gene.strand
# 1 NC_136047.1               10011040-10016688  -
# 2 NC_136047.1               10021967-10029276  -
# 3 NC_136047.1               10032360-10033427  -
# 4 NC_136047.1               10034020-10034731  -
# 5 NC_136047.1               10038273-10045182  -
# 6 NC_136047.1               10038273-10045182  -
#   previous.GeneID previous.gene.biotype previous.assembly.unit
# 1 NA              NA                    NA
# 2 NA              NA                    NA
# 3 NA              NA                    NA
# 4 NA              NA                    NA
# 5 NA              NA                    NA
# 6 NA              NA                    NA
#   previous.genomic.accession previous.gene.range previous.gene.strand
# 1 NA                         NA                  NA
# 2 NA                         NA                  NA
# 3 NA                         NA                  NA
# 4 NA                         NA                  NA
# 5 NA                         NA                  NA
# 6 NA                         NA                  NA
#   transcript.category current.transcript.accession current.protein.accession
# 1 Current-unmapped    XM_078466607.1               XP_078322733.1
# 2 Current-unmapped    XM_078466608.1               XP_078322734.1
# 3 NA                  NA                           NA
# 4 NA                  NA                           NA
# 5 Current-unmapped    XM_078466604.1               XP_078322730.1
# 6 Current-unmapped    XM_078466605.1               XP_078322731.1
#   current.transcript.range previous.transcript.accession
# 1 10011040-10016688        NA
# 2 10021967-10029276        NA
# 3 NA                       NA
# 4 NA                       NA
# 5 10038273-10045134        NA
# 6 10038273-10045181        NA
#   previous.protein.accession previous.transcript.range
# 1 NA                         NA
# 2 NA                         NA
# 3 NA                         NA
# 4 NA                         NA
# 5 NA                         NA
# 6 NA                         NA

# %% [markdown]
# ## 3. exploratory analysis

# %%
dim(annot)
# Out:
# [1] 97934    20

# %% [markdown]
# 97,934 rows - since there are only 35K-ish genes in the *C. virginica* genome, this doesn't necessarily mean one row = one gene

# %%
unique(annot$X.gene.category)
# Out:
#  [1] "Current-unmapped"      "Current-novel"         "Changed locus ID"
#  [4] "Similar"               "Changed substantially" "Current-other"
#  [7] "Changed locus type"    "Identical"             "Merged"
# [10] "Split"                 "Other"                 "Changed completeness"
# [13] "Previous-other"        "Previous-unmapped"     "Previous-novel"

# %% [markdown]
# I'm not too sure what each of these mean ... here's what I can find:
#
# **high-confidence matches**
# - Similar: very similar gene, small differences only
# - Identical: same gene model (exon structure and boundaries match perfectly)
#
# **structural or annotation changes**
# - Changed substantially: same locus but major differences (exon structure changed a lot, low overlap)
# - Changed locus type: gene biotype changed (e.g., protein-coding -> psuedogene)
# - Changed completeness: model completeness changed (e.g., gained/lost start/stop codon, partial <-> full length)
# - Changed locus ID: gene identifier reassigned (often due to merging/splitting/reclassification)
# - Split: one previous gene became multiple genes in current annotation
# - Merged: multiple previous genes combined in one current gene
#
# **newly appearing genes (no match previously)**
# - Current-unmapped: couldn't be mapped to previous assembly (e.g., assembly changed or region is absent)
# - Current-novel: newly annotated genes with no counterpart before
# - Current-other: new genes that don't fit cleanly into the above categories
#
# **disappearing genes (present before, gone now)**
# - Previous-unmapped: couldn't be mapped to current assembly
# - Previous-novel: previous gene annotations that don't have a counterpart in this new assembly
# - Previous-other: "disappearing" genes that don't fit cleanly into the above categories
#
# **catch-all/misc.**
# - Other

# %%
options(repr.plot.height = 5, repr.plot.width = 10)

ggplot(annot, aes(x = fct_infreq(X.gene.category), fill = X.gene.category)) +
geom_bar() +
coord_flip() +
theme_bw(base_size = 15) +
theme(legend.position = 'none') +
labs(x = 'Gene Category', title = 'New Release Oyster Reference Genome Annotations')
# Out:
# plot without title

# %% [markdown]
# so the majority of the gene annotations are similar to the previous gene - i'm curious to split these other categories up more

# %%
annot2 <- annot %>%
  separate(X.gene.category,
           into = c("status", "type"),
           sep = "-",
           fill = "left",
          remove = FALSE)

head(annot2)
# Out:
#   X.gene.category  status  type     current.GeneID current.gene.biotype
# 1 Current-unmapped Current unmapped 144622103      protein_coding
# 2 Current-unmapped Current unmapped 144622104      protein_coding
# 3 Current-unmapped Current unmapped 144620484      pseudogene
# 4 Current-unmapped Current unmapped 144620485      pseudogene
# 5 Current-unmapped Current unmapped 144622102      protein_coding
# 6 Current-unmapped Current unmapped 144622102      protein_coding
#   current.assembly.unit current.genomic.accession current.gene.range
# 1 GCF_053477295.1       NC_136047.1               10011040-10016688
# 2 GCF_053477295.1       NC_136047.1               10021967-10029276
# 3 GCF_053477295.1       NC_136047.1               10032360-10033427
# 4 GCF_053477295.1       NC_136047.1               10034020-10034731
# 5 GCF_053477295.1       NC_136047.1               10038273-10045182
# 6 GCF_053477295.1       NC_136047.1               10038273-10045182
#   current.gene.strand previous.GeneID ⋯ previous.genomic.accession
# 1 -                   NA              ⋯ NA
# 2 -                   NA              ⋯ NA
# 3 -                   NA              ⋯ NA
# 4 -                   NA              ⋯ NA
# 5 -                   NA              ⋯ NA
# 6 -                   NA              ⋯ NA
#   previous.gene.range previous.gene.strand transcript.category
# 1 NA                  NA                   Current-unmapped
# 2 NA                  NA                   Current-unmapped
# 3 NA                  NA                   NA
# 4 NA                  NA                   NA
# 5 NA                  NA                   Current-unmapped
# 6 NA                  NA                   Current-unmapped
#   current.transcript.accession current.protein.accession
# 1 XM_078466607.1               XP_078322733.1
# 2 XM_078466608.1               XP_078322734.1
# 3 NA                           NA
# 4 NA                           NA
# 5 XM_078466604.1               XP_078322730.1
# 6 XM_078466605.1               XP_078322731.1
#   current.transcript.range previous.transcript.accession
# 1 10011040-10016688        NA
# 2 10021967-10029276        NA
# 3 NA                       NA
# 4 NA                       NA
# 5 10038273-10045134        NA
# 6 10038273-10045181        NA
#   previous.protein.accession previous.transcript.range
# 1 NA                         NA
# 2 NA                         NA
# 3 NA                         NA
# 4 NA                         NA
# 5 NA                         NA
# 6 NA                         NA

# %%
options(repr.plot.height = 7.5, repr.plot.width = 15)

ggplot(annot2, aes(x = fct_infreq(type), fill = X.gene.category)) +
geom_bar() +
facet_wrap(~status, scales = 'free_x', nrow = 1) +
theme_bw(base_size = 15) +
theme(legend.position = 'none',
     axis.text.x = element_text(angle = 45, hjust = 1)) +
labs(x = 'Gene Category', title = 'New Release Oyster Reference Genome Annotations')
# Out:
# plot without title

# %% [markdown]
# What does this tell us?
# - most genes are similar to the previous annotation (yay!)
# - there are more removed genes than there are new genes (copmaring current box to previous box)
#     - the majority of the removed genes didn't align to the new assembly
#     - the majority of the new genes are new annotations that don't have a counterpart in the previous genome
